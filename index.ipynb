# %% [markdown]
# ## Feature Scaling and Normalization - Lab

# %% [markdown]
# ## Introduction
# In this lab, you'll practice your feature scaling and normalization skills!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Implement min-max scaling, mean-normalization, log normalization and unit vector normalization in python
# * Identify appropriate normalization and scaling techniques for given dataset

# %% [markdown]
# ## Back to our Boston Housing data

# %% [markdown]
# Let's import our Boston Housing data. Remember we categorized two variables and deleted the "NOX" (nitride oxide concentration) variable because it was highly correlated with two other features.

# %%
import pandas as pd
from sklearn.datasets import load_boston
boston = load_boston()

boston_features = pd.DataFrame(boston.data, columns = boston.feature_names)

# first, create bins for based on the values observed. 5 values will result in 4 bins
bins = [0, 3, 4 , 5, 24]
bins_rad = pd.cut(boston_features['RAD'], bins)
bins_rad = bins_rad.cat.as_unordered()

# first, create bins for based on the values observed. 5 values will result in 4 bins
bins = [0, 250, 300, 360, 460, 712]
bins_tax = pd.cut(boston_features['TAX'], bins)
bins_tax = bins_tax.cat.as_unordered()

tax_dummy = pd.get_dummies(bins_tax, prefix="TAX")
rad_dummy = pd.get_dummies(bins_rad, prefix="RAD")
boston_features = boston_features.drop(["RAD","TAX"], axis=1)
boston_features = pd.concat([boston_features, rad_dummy, tax_dummy], axis=1)
boston_features = boston_features.drop("NOX",axis=1)

# %% [markdown]
# ## Look at the histograms for the continuous variables

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
columns = list(boston_features.columns[0:5])

fig, axs = plt.subplots(1,5,figsize=(20,4),sharey=True)
for ax, column, index in zip(axs,columns, range(0,5)):
    ax.hist(boston_features[column])
    ax.set_xlabel(column)


columns = list(boston_features.columns[5:10])

fig, axs = plt.subplots(1,5,figsize=(20,4),sharey=True)
for ax, column, index in zip(axs, columns, range(0,5)):
    ax.hist(boston_features[column])
    ax.set_xlabel(column)

# %% [markdown]
# ## Perform log transformations for the variables where it makes sense

# %% [markdown]
# Analyze the results in terms of how they improved the normality performance. What is the problem with the "ZN" variable?

# %%
# log transform data to make the distribution look more normal

import numpy as np
data_log = pd.DataFrame([])
data_log["logCRIM"] = np.log(boston_features["CRIM"])
#data_log["logZN"] = np.log(boston_features["ZN"])
data_log["logINDUS"] = np.log(boston_features["INDUS"])
data_log["logAGE"] = np.log(boston_features["AGE"])
data_log["logDIS"] = np.log(boston_features["DIS"])
data_log["logPTRATIO"] = np.log(boston_features["PTRATIO"])
data_log["logB"] = np.log(boston_features["B"])
data_log["logLSTAT"] = np.log(boston_features["LSTAT"])
data_log.hist(figsize  = [6, 6]);

# %% [markdown]
# "ZN" has a lot of zeros (more than 50%!). Remember that this variable denoted: "proportion of residential land zoned for lots over 25,000 sq.ft.". It might have made sense to categorize this variable to "over 25,000 feet or not (binary variable 1/0). Now you have a zero-inflated variable which is cumbersome to work with.

# %% [markdown]
# ## Try different types of transformations on the continuous variables

# %% [markdown]
# Store your final features in a dataframe `features_final`

# %%
features_final = pd.DataFrame()
for column in data_log:
    data = data_log[column]
    features_final[column] = (data - np.mean(data))/(max(data)-min(data))
data = boston_features['ZN']
features_final['ZN'] = (data - np.mean(data))/(max(data)-min(data))
data = boston_features['RM']
features_final['RM'] = (data - np.mean(data))/(max(data)-min(data))

# %%
features_final
# Out:
#       logCRIM  logINDUS    logAGE    logDIS  logPTRATIO      logB  logLSTAT  \
# 0   -0.448432 -0.322716  0.024476  0.092905   -0.323068  0.032825 -0.247852
# 1   -0.295221 -0.049844  0.078345  0.174762   -0.051521  0.032825 -0.051253
# 2   -0.295297 -0.049844  0.006132  0.174762   -0.051521  0.031378 -0.316381
# 3   -0.277426 -0.336846 -0.075278  0.258703    0.036979  0.032020 -0.418482
# 4   -0.198116 -0.336846 -0.027714  0.258703    0.036979  0.032825 -0.225862
# 5   -0.285911 -0.336846 -0.005187  0.258703    0.036979  0.031838 -0.233234
# 6   -0.172385 -0.023695  0.030477  0.222308   -0.334834  0.032364  0.048289
# 7   -0.120775 -0.023695  0.134047  0.250868   -0.334834  0.032825  0.188216
# 8   -0.081061 -0.023695  0.145283  0.260084   -0.334834  0.029144  0.332795
# 9   -0.103773 -0.023695  0.102354  0.294009   -0.334834  0.029173  0.151558
# 10  -0.074506 -0.023695  0.128706  0.278026   -0.334834  0.031267  0.209481
# ...

# %%
features_final.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a26dd5f98>,
# ...
#       dtype=object)

# %% [markdown]
# ## Summary
# Great! You've now transformed your final data using feature scaling and normalization, and stored them in the `features_final` dataframe.
